# %%
#import all the libraries 
import time
from datetime import date, timedelta,datetime
import matplotlib.pyplot as plt 
#importing library and then initiating a chrome session and making request to login page of instagram
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
driver = webdriver.Chrome(executable_path = '/Users/Akshay/Downloads/chromedriver')
driver.get('https://www.instagram.com/')
time.sleep(5)
#searching for the username option and the fill the desired username to the send_keys function replacing USERNAME as a parameter 
username= driver.find_element_by_name("username")
username.send_keys("USERNAME")
#searching for the username option and the fill the desired password to the send_keys function replacing PASSWORD as a parameter
password= driver.find_element_by_name("password")
password.send_keys("PASSWORD")
#search for the submit button using xpath and class name and press on submit button 
sub= driver.find_element_by_xpath('//button[contains(@class, "sqdOP")]')
sub.submit()
#give time to login 
time.sleep(4)
try:
    notnow= driver.find_element_by_xpath('//div/button[contains(@class, "sqdOP yWX7d    y3zKF     ")]')
    notnow.click()
except NoSuchElementException :
    pass
time.sleep(1)
#press not now button
notnow= driver.find_element_by_xpath('//div/button[contains(@class, "aOOlW   HoLwm")]')
notnow.click()
time.sleep(1)

#now go to the search bar and type the text food to it 
s= driver.find_element_by_xpath('//input[contains(@class, "XTCLo")]')
s.send_keys("food")
time.sleep(3)
#now we search to get the text of all the usernames by selecting the correct class
a= driver.find_elements_by_xpath('//div[contains(@class, "_7UhW9   xLCgt       qyrsm KV-D4          uL8Hv         ")]')
#now we visit each element check if its a hashtag or not if not we print that directly as output 

for i in a[1:]:
    b=i.get_attribute('innerHTML')
    if b[0]!="#":
        print(b)
# Out:
# Getting Started
# sailusfood
# yourfoodlab
# your_foodienator_blogger17
# foodiesince96
# foodie_incarnate
# dilsefoodie
# food
# food_wackadoos
# foodinc.yumyumtree
# foodofgoa
# foodrush.recipe
# thisisdelhi
# foodinsider
# indianfood_lovers
# foodstrong.co
# foodbible
# meghnasfoodmagic
# ruchika_asatkar
# foodfoodtv
# ndtv_food
# fooddotcom
# healthfood
# foodproofofficial
# albaik
# foodrepublic
# thefood.vlogger
# foodiemoodie_duo
# fection_food
# foodsandflavorsbyshilpi
# foodconnectindia
# foodnetworkmag
# foody_cat
# foodelhi
# my_foodstory
# food_maple05
# bbcgoodfood
# delhi_streets_food
# mumbaifoodranger
# Food Street
# zofffoods
# foodyypreneur
# foodiesparsh
# foodieswithhoodies
# fao
# bikajifoods
# Food Mini
# reneechopra
# rajshrifood
